# %%
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from random import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

# %%
df = pd.read_csv('TimeSeries.csv')

# %%
del df['Time']

# %%
model = VAR(df)

# %%
results = model.fit(2)

# %%
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 04, Dec, 2019
# Time:                     03:30:55
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    21.7007
# Nobs:                     10969.0    HQIC:                   21.6963
# Log likelihood:          -150100.    FPE:                2.63992e+09
# AIC:                      21.6940    Det(Omega_mle):     2.63752e+09
# --------------------------------------------------------------------
# Results for equation IronAvgP
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const              149.142990        15.933801            9.360           0.000
# L1.IronAvgP          0.764926         0.009442           81.017           0.000
# L1.SteelAvgP        -0.002119         0.005670           -0.374           0.709
# L2.IronAvgP          0.150177         0.009442           15.906           0.000
# L2.SteelAvgP         0.004722         0.005669            0.833           0.405
# ===============================================================================
#
# Results for equation SteelAvgP
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const              668.130688        26.019765           25.678           0.000
# L1.IronAvgP          0.042207         0.015418            2.737           0.006
# L1.SteelAvgP         0.555487         0.009259           59.997           0.000
# L2.IronAvgP         -0.032339         0.015418           -2.097           0.036
# L2.SteelAvgP         0.244363         0.009257           26.397           0.000
# ===============================================================================
#
# Correlation matrix of residuals
#              IronAvgP  SteelAvgP
# IronAvgP     1.000000   0.000070
# SteelAvgP    0.000070   1.000000

# %%
results.plot()

# %%
results.plot_acorr()

# %%
irf = results.irf(10)

# %%
irf.plot(orth=False)

# %%
irf.plot(impulse='IronAvgP')

# %%
results.test_causality('IronAvgP', ['SteelAvgP'], kind='f')

# %%
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 04, Dec, 2019
# Time:                     03:34:25
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    21.7007
# Nobs:                     10969.0    HQIC:                   21.6963
# Log likelihood:          -150100.    FPE:                2.63992e+09
# AIC:                      21.6940    Det(Omega_mle):     2.63752e+09
# --------------------------------------------------------------------
# Results for equation IronAvgP
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const              149.142990        15.933801            9.360           0.000
# L1.IronAvgP          0.764926         0.009442           81.017           0.000
# L1.SteelAvgP        -0.002119         0.005670           -0.374           0.709
# L2.IronAvgP          0.150177         0.009442           15.906           0.000
# L2.SteelAvgP         0.004722         0.005669            0.833           0.405
# ===============================================================================
#
# Results for equation SteelAvgP
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const              668.130688        26.019765           25.678           0.000
# L1.IronAvgP          0.042207         0.015418            2.737           0.006
# L1.SteelAvgP         0.555487         0.009259           59.997           0.000
# L2.IronAvgP         -0.032339         0.015418           -2.097           0.036
# L2.SteelAvgP         0.244363         0.009257           26.397           0.000
# ===============================================================================
#
# Correlation matrix of residuals
#              IronAvgP  SteelAvgP
# IronAvgP     1.000000   0.000070
# SteelAvgP    0.000070   1.000000
